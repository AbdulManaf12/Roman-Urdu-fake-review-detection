# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Thesis_work/ML_experiments'
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/16LLv0tl9NuELAOpNIA0EW8v8njV1fcVa/Thesis_work/ML_experiments

# %% [markdown]
# #Loading libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn import metrics
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
#!pip install xgboost
from xgboost import XGBClassifier
import sklearn
import lightgbm as lgb
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #Method for confusion matrix plot

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score

def plot_confusion_matrix(Y, predicted):
  Y_predicted_classes = []
  for x in predicted:
    if x>=0.5:
        Y_predicted_classes.append(1)

    else:
        Y_predicted_classes.append(0)
#  print(len(Y), len(Y_predicted_classes))

  # accuracy: (tp + tn) / (p + n)
  accuracy = accuracy_score(Y, Y_predicted_classes)
  print('Accuracy: %f' % accuracy)
  # precision tp / (tp + fp)
  precision = precision_score(Y, Y_predicted_classes)
  print('Precision: %f' % precision)
  # recall: tp / (tp + fn)
  recall = recall_score(Y, Y_predicted_classes)
  print('Recall: %f' % recall)
  # f1: 2 tp / (2 tp + fp + fn)
  f1 = f1_score(Y, Y_predicted_classes)
  print('F1 score: %f' % f1)
  cf_matrix = confusion_matrix(Y,Y_predicted_classes)

  group_names = ['True Real','False Fake','False Real','True Fake']
  group_counts = ["{0:0.0f}".format(value) for value in
                  cf_matrix.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in
                      cf_matrix.flatten()/np.sum(cf_matrix)]
  labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
            zip(group_names,group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  print(labels.shape)
  print(cf_matrix.shape)
  sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

# %% [markdown]
# #Load the dataset

# %%
data = pd.read_csv('final_dataset_reviews_clean.csv')
data.head(2)
# Out:
#   Product_ID Customer_Name  Customer_ID        Date  Rating  Label  \
# 0   TE111EL1        itzmr7         6702  2019-11-09       1      0
# 1   MI543EL0        Afridi          396  2016-11-21       5      0
#
#                                              Reviews Sentiment  \
# 0      mil gya hai acha hai aur toota howa b nai hai  Positive
# 1  aram sy pocket may aa jta hai aur quality b ac...  Positive
#
#                         Features  length  ...  content_similarity  ext_score  \
# 0                      ['toota']      45  ...            0.051918          0
# 1  ['aram', 'pocket', 'quality']      52  ...            0.035987          1
#
#    IRS_score  ARD_Score  RD_Score                 Reviews_clean  \
# 0          1  -2.000000 -2.000000           acha tota howa nahi
# 1          1   0.466667  0.466667  aram pocket jta quality achi
#
#    Sentiment_class  length_clean words_clean  pid_encoded
# 0              1.0            19           4          539
# 1              1.0            28           5          336
#
# [2 rows x 23 columns]

# %% [markdown]
# #TRain and test data

# %%
spam_true = data[data['Label']==1]
spam_true=sklearn.utils.shuffle(spam_true, random_state=10)
print(spam_true.shape)
test_true = spam_true[:100]
train_true=spam_true[100:]
spam_false = data[data['Label']==0]
print(spam_false.shape)
spam_false=sklearn.utils.shuffle(spam_false, random_state=10)
test_false = spam_false[:100]
train_false=spam_false[100:]
train_data = pd.concat([train_true,train_false], ignore_index=True, sort=False)
train_data.to_csv('Spam_clean_train'+'.csv', index=False)
test_data = pd.concat([test_true,test_false],ignore_index=True, sort=False)
test_data.to_csv('Spam_clean_test'+'.csv', index=False)
# Out:
# (530, 23)
# (3393, 23)

# %%
df_train=pd.read_csv('Spam_clean_train.csv');
df_test=pd.read_csv('Spam_clean_test.csv');

# %%
df_train.head(10)
# Out:
#   Product_ID                                  Customer_Name  Customer_ID  \
# 0   VI363HL1                             Nasir Arafat Anwar         3953
# 1   UB622ME1                                          Hamza         2020
# 2   VE563HB0                                   Laraib elahi         2724
# 3   MA305FA1                                  Nabeel Naseer         3863
# 4   TH065EL1                                Zeeshan Nakhuda         6143
# 5   MA305FA1  &gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;www.richspath            1
# 6   AY536FA1                                  Farhan Bashir         1707
# 7   TD807EL1                                    Aamir Naeem          128
# 8   BO626EL1                                          Bilal         1273
# 9   LO108HB0                                     Haji Akber         1981
#
#          Date  Rating  Label  \
# 0  2017-07-03       5      1
# 1  2016-11-14       5      1
# 2  2020-01-14       5      1
# 3  2018-02-17       3      1
# 4  2019-01-03       4      1
# 5  2017-04-04       3      1
# 6  2020-01-03       3      1
# 7  2016-10-20       5      1
# 8  2018-03-10       5      1
# 9  2017-07-10       3      1
#
#                                              Reviews Sentiment  \
# 0  meri wife isse cooking mein istemaal kar rahi ...  Positive
# 1  bilkul seal pack haalat mein mila aur mein iss...  Negative
# 2                 mene usay kia tu pasnd aya mje bht   Neutral
# 3  yeh pack haasil karne mein yeh sab se roshan k...  Negative
# 4  nicer dicer se ab kaam pehlay se bhi zyada asa...  Positive
# 5  kya aap ke paas paiy _ account hai agar aap ap...  Positive
# 6  kaafi rough si feel hai iski pehnay mein comfo...  Positive
# 7  audio ki quality achi hai aur baki sb chezy b ...  Positive
# 8  bohat achaw microphone hai mehngay walay ki za...   Neutral
# 9  color bilkul natural lagta hai  mere hair colo...  Negative
#
#                                             Features  length  ...  \
# 0                                           ['wife']      73  ...
# 1    ['seal', 'pack', 'haalat', 'masnoaat', 'khush']      71  ...
# 2                                                 []      34  ...
# 3  ['pack', 'haasil', 'roshan', 'khayalat', 'qeem...     261  ...
# 4  ['nicer', 'dicer', 'pehlay', 'asan', 'sabziyan...     201  ...
# 5  ['paiy', 'account', 'account', 'din', 'ghantay...     176  ...
# 6  ['rough', 'feel', 'pehnay', 'comfortable', 'ka...     119  ...
# 7           ['audio', 'quality', 'chezy', 'balance']      57  ...
# 8      ['microphone', 'mehngay', 'zaroorat', 'best']      69  ...
# 9  ['color', 'natural', 'hair', 'color', 'match',...     288  ...
#
#    content_similarity  ext_score  IRS_score  ARD_Score  RD_Score  \
# 0            0.043131          1          0   2.250000  2.250000
# 1            0.053663          1          0   0.098039  0.333333
# 2            0.011511          1          1   0.000000  0.000000
# 3            0.073296          0          1  -0.832370 -0.832370
# 4            0.051853          1          1   0.111111  0.111111
# 5            0.033033          0          1  -0.832370 -0.832370
# 6            0.040672          0          1  -0.208333 -0.208333
# 7            0.036092          1          1   0.114286  0.114286
# 8            0.030766          1          0  -0.470588  1.000000
# 9            0.049036          0          1  -0.444444 -0.444444
#
#                                        Reviews_clean  Sentiment_class  \
# 0           meri wife coking istemal bohat kam araha              1.0
# 1          bilkul seal pack halat mila masnoat khush              0.0
# 2                         mene kia pasnd aya mje bht              0.5
# 3  pack hasil karne sab roshan khayalat nahi jais...              0.0
# 4  nicer dicer kam pehlay zyada asan hogaya sabzi...              1.0
# 5  ap pas paiy acount agar ap apne acount har din...              1.0
# 6  rough si fel iski pehnay comfortable liken kap...              1.0
# 7              audio quality achi baki chezy balance              1.0
# 8  bohat achaw microphone mehngay walay zarorat n...              0.5
# 9  color bilkul natural lagta mere hair color sah...              0.0
#
#    length_clean words_clean  pid_encoded
# 0            40           7          589
# 1            41           7          574
# 2            26           6          584
# 3           164          28          318
# 4           130          20          550
# 5           119          23          318
# 6            77          13           40
# 7            37           6          537
# 8            54           8           72
# 9           221          39          310
#
# [10 rows x 23 columns]

# %% [markdown]
# ##Features and label

# %%
X_train=df_train.drop(columns=[ 'Sentiment_class', 'Label','Sentiment','Date', 'Reviews', 'Reviews_clean', 'Features', 'Product_ID',	'Customer_Name'], axis =1, inplace=False)
X_test=df_test.drop(columns=[ 'Sentiment_class', 'Label','Sentiment','Date', 'Reviews', 'Reviews_clean', 'Features', 'Product_ID',	'Customer_Name'], axis =1, inplace=False)
y_train=df_train['Label']
y_test=df_test['Label']

# %%
X_train.head(2)
# Out:
#    Customer_ID  Rating  length  Activity_window  words_counts  pp1  \
# 0         3953       5      73              734            14  0.0
# 1         2020       5      71             1016            14  0.0
#
#    content_similarity  ext_score  IRS_score  ARD_Score  RD_Score  \
# 0            0.043131          1          0   2.250000  2.250000
# 1            0.053663          1          0   0.098039  0.333333
#
#    length_clean  words_clean  pid_encoded
# 0            40            7          589
# 1            41            7          574

# %% [markdown]
# #Resampling Technique RUS(Under sampling)

# %%
from sklearn.datasets import make_classification
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_ru, y_train_ru = rus.fit_resample(X_train, y_train)

# %%
X_train_ru.shape
# Out:
# (860, 14)

# %% [markdown]
# #Basic Classification Models

# %%
X_test.shape
# Out:
# (200, 14)

# %% [markdown]
# ##XGBoost

# %%
from sklearn.feature_selection import RFE
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
# fit model no training data
model = XGBClassifier(
                      learning_rate=0.01,
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      n_estimators=500,
                      reg_alpha = 0.3,
                      max_depth=10)

# rfe = RFE(model,n_features_to_select=7)
rfe = RFE(model)

#------Feature selection method-----------
fit = rfe.fit(X_train_ru, y_train_ru)
pred_xg = rfe.predict(X_test)
print("Num Features: %d" % fit.n_features_)
print("All features Ranking: %s" % list(map(lambda x, y: x+ ': ' +str(y), X_train.columns, fit.ranking_)))
print("Selected Features: %s" % X_train.columns[fit.support_])
#---Without feature selection and parameter tuning------
# pred_xg = model.predict(X_test)
# evaluate predictions
# Out:
# Num Features: 7
# All features Ranking: ['Customer_ID: 1', 'Rating: 1', 'length: 4', 'Activity_window: 1', 'words_counts: 2', 'pp1: 8', 'content_similarity: 7', 'ext_score: 1', 'IRS_score: 3', 'ARD_Score: 1', 'RD_Score: 1', 'length_clean: 5', 'words_clean: 6', 'pid_encoded: 1']
# Selected Features: Index(['Customer_ID', 'Rating', 'Activity_window', 'ext_score', 'ARD_Score',
#        'RD_Score', 'pid_encoded'],
#       dtype='object')

# %%
plot_confusion_matrix(y_test,pred_xg)
# Out:
# Accuracy: 0.790000
# Precision: 0.758929
# Recall: 0.850000
# F1 score: 0.801887
# (2, 2)
# (2, 2)

# %% [markdown]
# ##**Gradient Boosting**

# %%
model_gb = GradientBoostingClassifier(random_state=100, n_estimators=500,min_samples_split=10, max_depth=10)

#-------- Without Feature selection---------
# model_gb.fit(X_train_ru,y_train_ru)
# pred_gb = model_gb.predict(X_test)
# print(classification_report(y_test, pred_gb))

#-------- Random Eliminination Feature selection method------
rfe  = RFE(model_gb)
fit = rfe.fit(X_train_ru, y_train_ru)
pred_gb = rfe.predict(X_test)
print("Num Features: %d" % fit.n_features_)
print("All features Ranking: %s" % list(map(lambda x, y: x+ ': ' +str(y), X_train.columns, fit.ranking_)))
print("Selected Features: %s" % X_train.columns[fit.support_])
#-----evaluate results-----
plot_confusion_matrix(y_test,pred_gb)
# Out:
# Num Features: 7
# All features Ranking: ['Customer_ID: 1', 'Rating: 2', 'length: 1', 'Activity_window: 1', 'words_counts: 4', 'pp1: 8', 'content_similarity: 1', 'ext_score: 6', 'IRS_score: 7', 'ARD_Score: 1', 'RD_Score: 1', 'length_clean: 3', 'words_clean: 5', 'pid_encoded: 1']
# Selected Features: Index(['Customer_ID', 'length', 'Activity_window', 'content_similarity',
#        'ARD_Score', 'RD_Score', 'pid_encoded'],
#       dtype='object')
# Accuracy: 0.810000
# Precision: 0.798077
# Recall: 0.830000
# F1 score: 0.813725
# (2, 2)
# (2, 2)

# %% [markdown]
# ##Light GBM

# %%
model_lg = lgb.LGBMClassifier()

rfe  = RFE(model_lg)
fit = rfe.fit(X_train_ru, y_train_ru)
pred_lg = rfe.predict(X_test)
print("Num Features: %d" % fit.n_features_)
print("All features Ranking: %s" % list(map(lambda x, y: x+ ': ' +str(y), X_train.columns, fit.ranking_)))
print("Selected Features: %s" % X_train.columns[fit.support_])
plot_confusion_matrix(y_test,pred_lg)
# Out:
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000287 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1657
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1657
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1655
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000168 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1653
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1647
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1588
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000137 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1503
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 430, number of negative: 430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1269
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Num Features: 7
# All features Ranking: ['Customer_ID: 1', 'Rating: 5', 'length: 1', 'Activity_window: 1', 'words_counts: 3', 'pp1: 8', 'content_similarity: 1', 'ext_score: 7', 'IRS_score: 6', 'ARD_Score: 1', 'RD_Score: 1', 'length_clean: 2', 'words_clean: 4', 'pid_encoded: 1']
# Selected Features: Index(['Customer_ID', 'length', 'Activity_window', 'content_similarity',
#        'ARD_Score', 'RD_Score', 'pid_encoded'],
#       dtype='object')
# Accuracy: 0.800000
# Precision: 0.788462
# Recall: 0.820000
# F1 score: 0.803922
# (2, 2)
# (2, 2)

# %% [markdown]
# ##Decision Tree

# %%
model_dt = DecisionTreeClassifier()
##-----Without feature selection
# model_dt.fit(X_train_ru, y_train_ru)
# pred_dt = model_dt.predict(X_test)
rfe  = RFE(model_dt)
fit = rfe.fit(X_train_ru, y_train_ru)
pred_dt = rfe.predict(X_test)

print("Num Features: %d" % fit.n_features_)
print("All features Ranking: %s" % list(map(lambda x, y: x+ ': ' +str(y), X_train.columns, fit.ranking_)))
print("Selected Features: %s" % X_train.columns[fit.support_])

plot_confusion_matrix(y_test,pred_dt)
# Out:
# Num Features: 7
# All features Ranking: ['Customer_ID: 1', 'Rating: 4', 'length: 1', 'Activity_window: 1', 'words_counts: 3', 'pp1: 8', 'content_similarity: 1', 'ext_score: 7', 'IRS_score: 6', 'ARD_Score: 1', 'RD_Score: 1', 'length_clean: 2', 'words_clean: 5', 'pid_encoded: 1']
# Selected Features: Index(['Customer_ID', 'length', 'Activity_window', 'content_similarity',
#        'ARD_Score', 'RD_Score', 'pid_encoded'],
#       dtype='object')
# Accuracy: 0.640000
# Precision: 0.640000
# Recall: 0.640000
# F1 score: 0.640000
# (2, 2)
# (2, 2)

# %% [markdown]
# ##**Random Forest Classifier**

# %%
model_rf = RandomForestClassifier(n_estimators=110)
# model_rf.fit(X_train_ru,y_train_ru)
rfe  = RFE(model_rf)
fit = rfe.fit(X_train_ru, y_train_ru)
pred_rf = rfe.predict(X_test)
print('accuracy %s' % accuracy_score(pred_rf, y_test))
#print(classification_report(y_test, pred_rf))
plot_confusion_matrix(y_test,pred_rf)
# Out:
# accuracy 0.7
# Accuracy: 0.700000
# Precision: 0.717391
# Recall: 0.660000
# F1 score: 0.687500
# (2, 2)
# (2, 2)

# %% [markdown]
# ##feature scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
X_train = MinMaxScaler().fit_transform(X_train)
X_test = MinMaxScaler().fit_transform(X_test)
# X_train = StandardScaler().fit_transform(X_train)
# X_test = StandardScaler().fit_transform(X_test)

# %% [markdown]
# ##Naive bayes

# %%
#Bernoulli Navie Bayes Classifier
BNB_Classifier = BernoulliNB()
BNB_Classifier.fit(X_train_ru, y_train_ru)
pred_nb = BNB_Classifier.predict(X_test)
# print("\nClassification report for BernoulliNB Classifier %s:\n%s\n" % (BNB_Classifier, metrics.classification_report(y_test, pred_nb)))
plot_confusion_matrix(y_test,pred_nb)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# Accuracy: 0.480000
# Precision: 0.489130
# Recall: 0.900000
# F1 score: 0.633803
# (2, 2)
# (2, 2)

# %%
#Bernoulli Navie Bayes Classifier
GNB_Classifier = GaussianNB()
GNB_Classifier.fit(X_train_ru, y_train_ru)
GNB_Predictions =  GNB_Classifier.predict(X_test)
plot_confusion_matrix(y_test,GNB_Predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.500000
# Precision: 0.000000
# Recall: 0.000000
# F1 score: 0.000000
# (2, 2)
# (2, 2)

# %% [markdown]
# ##Logistic REgression

# %%
LR_Classifier = LogisticRegression()
LR_Classifier.fit(X_train_ru, y_train_ru)
pred_lr = LR_Classifier.predict(X_test)
plot_confusion_matrix(y_test,pred_lr)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Accuracy: 0.590000
# Precision: 0.550562
# Recall: 0.980000
# F1 score: 0.705036
# (2, 2)
# (2, 2)

# %% [markdown]
# ##Support VEctor

# %%
#SVC Classifier
SVC_Classifier = SVC()
SVC_Classifier.fit(X_train_ru, y_train_ru)
pred_svc = SVC_Classifier.predict(X_test)
plot_confusion_matrix(y_test,pred_svc)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.500000
# Precision: 0.000000
# Recall: 0.000000
# F1 score: 0.000000
# (2, 2)
# (2, 2)

# %% [markdown]
# ##**Stochastic Gradient Descent**

# %%
model_sg = SGDClassifier()
model_sg.fit(X_train_ru,y_train_ru)
pred_sg = model_sg.predict(X_test)
plot_confusion_matrix(y_test,pred_sg)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(
# Accuracy: 0.580000
# Precision: 0.544444
# Recall: 0.980000
# F1 score: 0.700000
# (2, 2)
# (2, 2)

# %% [markdown]
# ##ANN

# %%
X_train_ru.shape[1]
# Out:
# 14

# %%
from keras import models
from keras import layers
dnn = models.Sequential()
dnn.add(layers.Dense(16, activation = 'relu', input_shape=(X_train_ru.shape[1],)))
dnn.add(layers.Dropout(0.3))
dnn.add(layers.Dense(8, activation = 'relu', input_shape=(X_train_ru.shape[1],)))

dnn.add(layers.Dense(1, activation = 'sigmoid'))

dnn.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])


history = dnn.fit(X_train_ru,
                  y_train_ru,
                    batch_size=40)

dnn.evaluate(X_test,y_test)
# Out:
# 22/22 [==============================] - 4s 4ms/step - loss: 61.2132 - accuracy: 0.5291
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7009 - accuracy: 0.5400
# [0.7008806467056274, 0.5400000214576721]

# %%
pred_ann = model_sg.predict(X_test)
plot_confusion_matrix(y_test,pred_ann)
# Out:
# Accuracy: 0.580000
# Precision: 0.544444
# Recall: 0.980000
# F1 score: 0.700000
# (2, 2)
# (2, 2)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #**Best model Accuracy and F-score**
#
# We tested six different models and now, we check which one is the best:

# %%
xg_acc = accuracy_score(pred_xg, y_test)
gb_acc = accuracy_score(pred_gb, y_test)
nb_acc = accuracy_score(pred_nb, y_test)
rf_acc = accuracy_score(pred_rf, y_test)
sg_acc = accuracy_score(pred_sg, y_test)
svm_acc = accuracy_score(pred_svc, y_test)
lr_acc = accuracy_score(pred_lr, y_test)
dt_acc = accuracy_score(pred_dt, y_test)
ann_acc = accuracy_score(pred_ann, y_test)
lgb_acc = accuracy_score(pred_lg,y_test)


xg_f1 = f1_score(pred_xg, y_test)
gb_f1 = f1_score(pred_gb, y_test)
nb_f1 = f1_score(pred_nb, y_test)
rf_f1 = f1_score(pred_rf, y_test)
sg_f1 = f1_score(pred_sg, y_test)
svm_f1 = f1_score(pred_svc, y_test)
lr_f1 = f1_score(pred_lr, y_test)
dt_f1 = f1_score(pred_dt, y_test)
ann_f1 = f1_score(pred_ann, y_test)
lgb_f1 = f1_score(pred_lg,y_test)

# %%
models = pd.DataFrame({
                      'Model': ['Extreme Gradient', 'Light GBM', 'Naive Bayes', 'Random Forest', 'Gradient Boosting', 'SVM', 'SGD', 'Logistic Regression', 'Decision Tree', 'ANN'],
                      'Accuracy': [xg_acc, lgb_acc, nb_acc, rf_acc, gb_acc, svm_acc, sg_acc, lr_acc, dt_acc, ann_acc],
                      'F-Score': [xg_f1,lgb_f1, nb_f1, rf_f1, gb_f1, svm_f1, sg_f1, lr_f1, dt_f1, ann_f1]
                       })
models.sort_values(by='F-Score', ascending=False, inplace=True)
models.reset_index()
# Out:
#    index                Model  Accuracy   F-Score
# 0      4    Gradient Boosting      0.81  0.813725
# 1      1            Light GBM      0.80  0.803922
# 2      0     Extreme Gradient      0.79  0.801887
# 3      7  Logistic Regression      0.59  0.705036
# 4      6                  SGD      0.58  0.700000
# 5      9                  ANN      0.58  0.700000
# 6      3        Random Forest      0.70  0.687500
# 7      8        Decision Tree      0.64  0.640000
# 8      2          Naive Bayes      0.48  0.633803
# 9      5                  SVM      0.50  0.000000

# %%
models.to_csv("paper/expsettingV_RUS_RFE.csv", index=False)

# %% [markdown]
# #Grouped confusion matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
fig, axes = plt.subplots(4, 3, figsize=(16, 18))

def plot_grouped_cm(Y, predicted, r,c, model):
  Y_predicted_classes = []
  for x in predicted:
    if x>=0.5:
        Y_predicted_classes.append(1)

    else:
        Y_predicted_classes.append(0)
#  print(len(Y), len(Y_predicted_classes))
  cf_matrix = confusion_matrix(Y,Y_predicted_classes)

  group_names = ['True Real','False Fake','False Real','True Fake']
  group_counts = ["{0:0.0f}".format(value) for value in
                  cf_matrix.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in
                      cf_matrix.flatten()/np.sum(cf_matrix)]
  labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
            zip(group_names,group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  print(labels.shape)
  print(cf_matrix.shape)
  sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues', ax =axes[r,c])
  axes[r,c].set_title(model)
xg_acc, lgb_acc, nb_acc, rf_acc, gb_acc, svm_acc, sg_acc, lr_acc, dt_acc, ann_acc
plot_grouped_cm(y_test, pred_xg, 0,0, 'Extreme Gradient')
plot_grouped_cm(y_test, pred_lg, 0,1, 'Light GBM')
plot_grouped_cm(y_test, pred_nb, 0,2, 'Naive Bayes')
plot_grouped_cm(y_test, pred_rf, 1,0, 'Random Forest')
plot_grouped_cm(y_test, pred_gb, 1,1, 'Gradient Boosting')

plot_grouped_cm(y_test, pred_svc, 1,2, 'Support Vector')
plot_grouped_cm(y_test, pred_sg, 2,0, 'stochastic gradient')
plot_grouped_cm(y_test, pred_lr, 2,1, 'Logistic Regression')
plot_grouped_cm(y_test, pred_dt, 2,2, 'Decision Tree')
plot_grouped_cm(y_test, pred_ann, 3,0, 'Neural Network')



fig.tight_layout()
fig.savefig("paper/expsettingV_RUS_RFE.png")
# Out:
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
# (2, 2)
